# %% [markdown]
# <a href="https://colab.research.google.com/github/manishkumar09789/DATA-SCIENCE_1_PROJECT/blob/main/Custumer_purchase_LR_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path="/content/Customer Purchasing Behaviors.csv"
df=pd.read_csv(path)
df
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# ..       ...  ...            ...              ...            ...    ...
# 233      234   40          60000              450            7.2   West
# 234      235   38          59000              430            6.9  North
# 235      236   54          74000              630            9.4  South
# 236      237   32          52000              360            5.8   West
# 237      238   31          51000              340            5.6  North
#
#      purchase_frequency
# 0                    12
# 1                    18
# 2                    22
# ...

# %%
x=(df["annual_income"])
y=(df["purchase_amount"])
print(x,y)
# Out:
# 0      45000
# 1      55000
# 2      65000
# 3      30000
# 4      47000
#        ...
# 233    60000
# 234    59000
# 235    74000
# 236    52000
# 237    51000
# Name: annual_income, Length: 238, dtype: int64 0      200
# 1      350
# 2      500
# 3      150
# 4      220
#       ...
# 233    450
# 234    430
# 235    630
# 236    360
# 237    340
# Name: purchase_amount, Length: 238, dtype: int64

# %%
mean_x=sum(x)/len(x)
mean_y=sum(y)/len(y)
print(mean_x,mean_y)
# Out:
# 57407.56302521008 425.6302521008403

# %%
numer=0
denom=0
for i in range(len(x)):
  numer+=(x[i]-mean_x)*(y[i]-mean_y)
  denom+=(x[i]-mean_x)**2
  m=numer/denom
  c=mean_y-(m*mean_x)
print(m,c)
# Out:
# 0.012087155778828688 -268.26390506779984

# %%
import matplotlib.pyplot as plt
import numpy as np
max_x=np.max(x)+5
min_x=np.min(x)-5
a=np.linspace(min_x,max_x)
b=m*a+c
plt.plot(a,b,color='red')
plt.scatter(x,y,color='blue')
plt.xlabel("annual_income")
plt.ylabel("purchase_amount")
plt.show()

# %%
x=25000
y=m*x+c
print(y)
# Out:
# 33.91498940291734
